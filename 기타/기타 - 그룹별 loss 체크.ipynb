# %% [markdown]
# **Todo**:
# 1. Transform features (must understand the sensor data before
# 2. Remove unnecessary features (using what? correlation matrix, random forest, pca, ...)
# 3. Combine different regression models (ensemble model) to evaluate the test dataset
# 3. Try Deep Learning (Autoencoder, Vanilla... on google colab or on gpu server if you have an access)
# 4. Look into paperswithcode website for experimental model
# 5. Think about how to make a learning model explainable for decision
# 6. Do some EDAs, don't have to be fancy or anything
# 7. Post random code on the dacon website; uploading a code is part of the grade
#
#
# possibly more...

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import random
import os
import numpy as np
import optuna
import seaborn as sns
import matplotlib.pyplot as plt
from functools import partial
from lightgbm import LGBMRegressor
from hyperopt import fmin, hp, tpe, atpe
from sklearn.linear_model import LinearRegression
from sklearn.multioutput import MultiOutputRegressor
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas_profiling
import ipywidgets
# 시각화
import missingno
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [108], in <cell line: 18>()
#      16 from sklearn.preprocessing import StandardScaler
#      17 import pandas_profiling
# ---> 18 import ipywidgets
#      19 # 시각화
#      20 import missingno
#
# ModuleNotFoundError: No module named 'ipywidgets'

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed_everything(42) # Seed 고정

# %% [markdown]
# ### Usable Functions

# %%
def dataset_split_X_y(df):    
    """
    @Description: split data into features and labels
    @Param: df, pandas dataframe with columns starting with X for features and Y for labels
    @Return: features and labels in pandas dataframes
    """
    xs = df.filter(regex='X') # Input : X Featrue
    ys = df.filter(regex='Y') # Output : Y Feature
    return xs, ys

# %%
def check_for_NAs(df, show=False):
    """
    @Description: checks for the NAs in the dataframe
    @Param1: df, pandas dataframe
    @Param2: show, boolean indicating whether NaN data are also necessary as a part of the output
    @Return: name of the columns with NaN
    """
    nan_values = df.loc[:, df.isnull().any()]
    if show:
        return df[df.isna().any(axis=1)]
    return list(nan_values.columns)

# %%
def check_for_label_bound(df, labels, bound):
    """
    @Description: check bound is inbetween min and max
    @Param1: df, pandas dataframe
    @Param2: labels, list of column names 
    @Param3: thres: list of bounds
    @Return: names of the columns not within the bound
    """
    n = len(labels)
    result = []
    for idx in range(n):
        col = labels[idx]
        thres = bound[idx]
        extracted_column = df[col]
        if not extracted_column.between(thres[0], thres[1]).all():
            result.append(labels[idx])
    if len(result) == 0:
        print('everything is within the bound')
    return result

# %%
def zero_variance(df):
    """
    @Description: check for zero_variance
    @Param1: df, pandas dataframe
    @Return: names of the columns with zero variance
    """
    result = []
    for col in train_x.columns:
        if train_x[col].var() == 0:
            result.append(col)
    return result

# %%
def get_top_correlation(df, n=10):
    """
    @Description: print out top correlated features
    @Param1: df, pandas dataframe
    @Param2: n, number of lines to print 
    @Return: pandas series
    """
    pairs = set()
    for idx1 in range(0, df.shape[1]):
        for idx2 in range(0, idx1+1):
            pairs.add((df.columns[idx1], df.columns[idx2]))
    corr = df.corr().abs().unstack()
    corr = corr.drop(labels=pairs).sort_values(ascending=False)
    return corr[0:n]

# %%
def adjacent_histogram_boxplot(feature_var, figsize = (7, 5)):
    """
    @Description: plot histogram and boxplot in next to each other
    @Param1: feature_var, pandas series 
    @Param2: figsize, size of the figure 
    """
    fig, (hist_plot, box_plot) = plt.subplots(nrows=2, sharex=True, gridspec_kw={'height_ratios':(.85,.15)}, figsize=figsize)
    sns.distplot(feature_var, kde=True, ax=hist_plot, kde_kws= {"linewidth":1.5}) 
    sns.boxplot(feature_var, ax=box_plot, linewidth = 1, width = 0.5)
    hist_plot.set_ylabel('')    
    hist_plot.set_xlabel('')
    box_plot.set_xlabel('')
    hist_plot.tick_params(labelsize=8)
    box_plot.tick_params(labelsize=8)
    fig.suptitle(feature_var.name, fontsize = 10)
    hist_plot.axvline(np.mean(feature_var),color='red',linestyle='-',lw = 1.5)
    hist_plot.axvline(np.median(feature_var),color='green',linestyle='--',lw = 1.5)

# %%
def lg_nrmse(gt, preds):
    """
    @Description: Metric used in this project
    @Params1: gt, pandas dataframe
    @Param2: preds, pandas dataframe
    @Return: nrmse score
    """
    # 각 Y Feature별 NRMSE 총합
    # Y_01 ~ Y_08 까지 20% 가중치 부여
    preds = pd.DataFrame(preds)
    all_nrmse = []
    for idx in range(0,14):
        rmse = mean_squared_error(gt.iloc[:,idx], preds.iloc[:,idx], squared=False)
        nrmse = rmse/np.mean(np.abs(gt.iloc[:,idx]))
        all_nrmse.append(nrmse)
    score = 1.2 * np.sum(all_nrmse[:8]) + 1.0 * np.sum(all_nrmse[8:15])
    return score

# %%
# ys = ['Y_01', 'Y_02', 'Y_03', 'Y_04', 'Y_05', 
#       'Y_06', 'Y_07', 'Y_08', 'Y_09', 'Y_10', 
#       'Y_11', 'Y_12', 'Y_13', 'Y_14']
# ys_bounds = [[0.2, 2], [0.2, 2.1], [0.2, 2.1], 
#              [7, 19], [22, 36.5], [-19.2, 19], 
#              [2.4, 4], [-29.2, -24], [-29.2, -24],
#              [-30.6, -20], [19.6, 26.6], [-29.2, -24],
#              [-29.2, -24], [-29.2, -24]]

# %% [markdown]
# ### Load Dataset

# %%
train_df = pd.read_csv('./train.csv')
test_x = pd.read_csv('./test.csv')
train_x, train_y = dataset_split_X_y(train_df)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
pr=train_df.profile_report()

# %%
pr.to_file('pr_report.html')
# Out:
# Summarize dataset: 100%|██████████| 4180/4180 [06:57<00:00, 10.01it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:16<00:00, 16.38s/it]
# Render HTML: 100%|██████████| 1/1 [01:32<00:00, 92.75s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00,  1.73it/s]

# %%
missingno.matrix(train_df, figsize = (15,8))
# Out:
# <AxesSubplot:>

# %%
train_df.isnull().sum()
# Out:
# ID      0
# X_01    0
# X_02    0
# X_03    0
# X_04    0
#        ..
# Y_10    0
# Y_11    0
# Y_12    0
# Y_13    0
# Y_14    0
# Length: 71, dtype: int64

# %%
# Co-relation 매트릭스
corr = train_df.corr()
# 마스크 셋업
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# 그래프 셋업
plt.figure(figsize=(14, 8))
# 그래프 타이틀
plt.title('Overall Correlation of Titanic Features', fontsize=18)
# Co-relation 매트릭스 런칭
sns.heatmap(corr, mask=mask, annot=False,cmap='RdYlGn', linewidths=0.2, annot_kws={'size':20})
plt.show()
# Out:
# C:\Users\Dohyeong Seo\AppData\Local\Temp\ipykernel_9544\3403182845.py:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)

# %%
train_g1 = pd.concat([train_x.iloc[:, :2], train_x.iloc[:, 4:6]], axis=1)

# %%
train_g1.describe()
# Out:
#                X_01          X_02          X_05          X_06
# count  39607.000000  39607.000000  39607.000000  39607.000000
# mean      68.412040    103.320166    102.337203     70.597211
# std        2.655983      0.000372      0.548353      2.259820
# min       56.268000    103.320000    101.774000     61.726000
# 25%       66.465000    103.320000    101.949000     68.864000
# 50%       68.504000    103.320000    102.006000     69.884000
# 75%       69.524000    103.320000    103.144000     71.923000
# max       84.820000    103.321000    103.160000     87.219000

# %%
# PCB 체결 시 단계별 누름량 (1~4)
plt.figure(figsize=(30,5))
plt.plot(train_g1, label='train_g1')
plt.legend()
plt.show()

# %%
# n번 안테나 패드 위치
train_g2 = train_x.iloc[:, 13:18]

# %%
train_g2.describe()
# Out:
#                X_14          X_15          X_16          X_17          X_18
# count  39607.000000  39607.000000  39607.000000  39607.000000  39607.000000
# mean      13.372201     13.381914     13.463860     13.512589     13.449263
# std        0.029865      0.029468      0.036741      0.023436      0.029093
# min       13.150000     13.230000     13.260000     13.410000     13.260000
# 25%       13.350000     13.360000     13.440000     13.500000     13.430000
# 50%       13.370000     13.380000     13.470000     13.510000     13.450000
# 75%       13.390000     13.410000     13.490000     13.530000     13.470000
# max       13.490000     13.500000     13.610000     13.610000     13.570000

# %%
# PCB 체결 시 단계별 누름량 (1~4)
plt.figure(figsize=(30,5))
plt.plot(train_g2, label='train_g2')
plt.legend()
plt.show()

# %%
# 레이돔 치수 & 기울기
train_g3 = train_x.iloc[:, 40:45]

# %%
train_g3.describe()
# Out:
#                X_41          X_42          X_43          X_44          X_45
# count  39607.000000  39607.000000  39607.000000  39607.000000  39607.000000
# mean      21.186992     21.059334     21.203705     21.160107      0.154567
# std        0.031128      0.040288      0.047211      0.042176      0.046968
# min       20.730000     20.790000     20.800000     20.930000      0.000000
# 25%       21.170000     21.030000     21.170000     21.130000      0.120000
# 50%       21.190000     21.060000     21.200000     21.160000      0.150000
# 75%       21.210000     21.090000     21.240000     21.190000      0.190000
# max       21.620000     21.440000     21.410000     21.320000      0.420000

# %%
# PCB 체결 시 단계별 누름량 (1~4)
plt.figure(figsize=(30,5))
plt.plot(train_g3, label='train_g3')
plt.legend()
plt.show()

# %%
adjacent_histogram_boxplot(train_g3.iloc[:, 0])

# %%
train_x.iloc[:, :10].describe()
# Out:
#                X_01          X_02          X_03     X_04          X_05  \
# count  39607.000000  39607.000000  39607.000000  39607.0  39607.000000
# mean      68.412040    103.320166     68.826354      1.0    102.337203
# std        2.655983      0.000372      5.151167      0.0      0.548353
# min       56.268000    103.320000     56.470000      1.0    101.774000
# 25%       66.465000    103.320000     65.070000      1.0    101.949000
# 50%       68.504000    103.320000     67.270000      1.0    102.006000
# 75%       69.524000    103.320000     71.770000      1.0    103.144000
# max       84.820000    103.321000     89.170000      1.0    103.160000
#
#                X_06          X_07          X_08          X_09          X_10
# count  39607.000000  39607.000000  39607.000000  39607.000000  39607.000000
# mean      70.597211     29.407490    164.449320    225.397470      0.002449
# std        2.259820      7.338204    220.402444     66.734725      0.086255
# min       61.726000     14.140000     38.460000     37.580000      0.000000
# 25%       68.864000     27.890000    105.990000    188.540000      0.000000
# 50%       69.884000     28.840000    115.040000    234.450000      0.000000
# 75%       71.923000     29.870000    132.620000    263.960000      0.000000
# max       87.219000    163.860000   2387.440000    637.490000      3.600000

# %%
x01 = train_x.iloc[:, :10].iloc[:, 0]
adjacent_histogram_boxplot(x01)
# Out:
# D:\ai\envs\dacon\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\ai\envs\dacon\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
train_x.iloc[:, 10:20].describe()
# Out:
#                X_11          X_12          X_13          X_14          X_15  \
# count  39607.000000  39607.000000  39607.000000  39607.000000  39607.000000
# mean       0.000366      4.373228      0.143335     13.372201     13.381914
# std        0.014145      0.021806      0.025334      0.029865      0.029468
# min        0.000000      4.270000      0.050000     13.150000     13.230000
# 25%        0.000000      4.360000      0.130000     13.350000     13.360000
# 50%        0.000000      4.370000      0.140000     13.370000     13.380000
# 75%        0.000000      4.390000      0.160000     13.390000     13.410000
# max        0.700000      4.490000      0.280000     13.490000     13.500000
#
#                X_16          X_17          X_18          X_19          X_20
# count  39607.000000  39607.000000  39607.000000  39607.000000  39607.000000
# mean      13.463860     13.512589     13.449263      3.240229      3.184493
# std        0.036741      0.023436      0.029093      0.110482      0.105266
# min       13.260000     13.410000     13.260000      2.860000      2.830000
# 25%       13.440000     13.500000     13.430000      3.160000      3.100000
# 50%       13.470000     13.510000     13.450000      3.220000      3.180000
# 75%       13.490000     13.530000     13.470000      3.310000      3.270000
# max       13.610000     13.610000     13.570000      3.750000      3.670000

# %%
train_x.iloc[:, 20:30].describe()
# Out:
#                X_21          X_22     X_23          X_24          X_25  \
# count  39607.000000  39607.000000  39607.0  39607.000000  39607.000000
# mean       3.174270      3.232673      1.0      2.115674      2.093895
# std        0.106868      0.108981      0.0      0.032440      0.033148
# min        2.830000      2.850000      1.0      1.830000      1.960000
# 25%        3.090000      3.140000      1.0      2.090000      2.070000
# 50%        3.160000      3.230000      1.0      2.120000      2.090000
# 75%        3.250000      3.320000      1.0      2.140000      2.120000
# max        3.680000      3.790000      1.0      2.350000      2.350000
#
#                X_26          X_27          X_28          X_29          X_30
# count  39607.000000  39607.000000  39607.000000  39607.000000  39607.000000
# mean       2.090377      2.098249      2.118594      2.173727      1.378994
# std        0.038512      0.038056      0.042782      0.046689      0.030412
# min        1.980000      1.990000      1.930000      2.020000      0.570000
# 25%        2.060000      2.070000      2.090000      2.140000      1.370000
# 50%        2.090000      2.090000      2.120000      2.170000      1.370000
# 75%        2.120000      2.120000      2.140000      2.200000      1.380000
# max        2.350000      2.350000      2.350000      2.360000      2.110000

# %%
train_x.iloc[:, 30:40].describe()
# Out:
#                X_31          X_32          X_33          X_34          X_35  \
# count  39607.000000  39607.000000  39607.000000  39607.000000  39607.000000
# mean       1.571141      1.362929      1.595723     12.950271     12.920343
# std        0.074520      0.029945      0.108028      0.044030      0.052238
# min        0.600000      0.570000      0.610000     12.840000     12.810000
# 25%        1.530000      1.350000      1.550000     12.920000     12.870000
# 50%        1.550000      1.360000      1.570000     12.960000     12.920000
# 75%        1.600000      1.370000      1.610000     12.990000     12.970000
# max        7.210000      2.450000      7.810000     13.080000     13.090000
#
#                X_36          X_37          X_38          X_39          X_40
# count  39607.000000  39607.000000  39607.000000  39607.000000  39607.000000
# mean      12.941728     12.919139    -15.903737    -15.889576    -16.572162
# std        0.047830      0.052292      0.595420      0.746665      0.344486
# min       12.840000     12.810000    -17.090000    -17.090000    -17.720000
# 25%       12.900000     12.870000    -16.160000    -16.160000    -16.810000
# 50%       12.950000     12.910000    -15.990000    -15.990000    -16.640000
# 75%       12.980000     12.970000    -15.750000    -15.750000    -16.400000
# max       13.090000     13.080000     32.230000     -2.650000    -14.800000

# %%
train_x.iloc[:, 40:50].describe()
# Out:
#                X_41          X_42          X_43          X_44          X_45  \
# count  39607.000000  39607.000000  39607.000000  39607.000000  39607.000000
# mean      21.186992     21.059334     21.203705     21.160107      0.154567
# std        0.031128      0.040288      0.047211      0.042176      0.046968
# min       20.730000     20.790000     20.800000     20.930000      0.000000
# 25%       21.170000     21.030000     21.170000     21.130000      0.120000
# 50%       21.190000     21.060000     21.200000     21.160000      0.150000
# 75%       21.210000     21.090000     21.240000     21.190000      0.190000
# max       21.620000     21.440000     21.410000     21.320000      0.420000
#
#                X_46     X_47     X_48           X_49          X_50
# count  39607.000000  39607.0  39607.0   39607.000000  39607.000000
# mean    1468.275305      1.0      1.0   16676.913639    130.774557
# std        2.121517      0.0      0.0    8584.427420      5.989845
# min     1457.000000      1.0      1.0    3341.830000     21.800000
# 25%     1469.000000      1.0      1.0   13093.930000    126.948571
# 50%     1469.000000      1.0      1.0   15273.330000    130.723378
# 75%     1469.000000      1.0      1.0   17560.180000    134.538998
# max     1469.000000      1.0      1.0  114563.630000    162.619458

# %%
train_x.iloc[:, 50:].describe()
# Out:
#                X_51          X_52          X_53          X_54          X_55  \
# count  39607.000000  39607.000000  39607.000000  39607.000000  39607.000000
# mean     131.457418    138.587595    127.992420    128.014110    137.884711
# std        5.934313      6.469813      5.713153      5.433958      6.552101
# min       21.910000     23.100000     21.330000     21.340000     22.980000
# 25%      127.669758    134.475401    124.374525    124.697879    133.744103
# 50%      131.352856    138.525575    128.020010    128.098728    137.900952
# 75%      135.170761    142.702448    131.618662    131.487423    142.073102
# max      194.513195    173.438623    152.406630    175.052891    170.155980
#
#                X_56
# count  39607.000000
# mean     128.441119
# std        5.444245
# min       21.410000
# 25%      125.134713
# 50%      128.414501
# 75%      131.839764
# max      155.277538

# %% [markdown]
# ### Feature Selection
# Need to spend more time on this!
#
# Must understand the nature of the data (sensor) to get better performance

# %%
cols_with_zero_variance = zero_variance(train_x)
train_x = train_x.drop(cols_with_zero_variance, axis = 1)

test_x = test_x.drop(cols_with_zero_variance, axis = 1)

highly_correlated = [i[1] for i in get_top_correlation(train_x, 7).index]
train_x = train_x.drop(highly_correlated, axis = 1)

test_x = test_x.drop(highly_correlated, axis = 1)
test_x = test_x.drop('ID', axis=1)

# %% [markdown]
# ### Train
# Train dataset is again splitted into train and validation set

# %%
def evaluate(params, x_train, y_train, x_test, y_test):
    model = MultiOutputRegressor(LGBMRegressor(objective='regression', n_jobs=-1, **params))
    model.fit(x_train, y_train)
    pred = model.predict(x_test)
    nrmse = lg_nrmse(y_test, pred)
    return nrmse

# %%
train_X, validation_X, train_Y, validation_Y = train_test_split(train_g1, train_y, test_size = 0.2, )

# %%
train_X, validation_X, train_Y, validation_Y = train_test_split(train_g2, train_y, test_size = 0.2, )

# %%
train_X, validation_X, train_Y, validation_Y = train_test_split(train_g3, train_y, test_size = 0.2, )

# %%
train_X, validation_X, train_Y, validation_Y = train_test_split(train_x, train_y, test_size = 0.2, )

# %%
lgb_params_space = {
    'max_depth':        hp.choice('max_depth',        np.arange(3, 16, 1, dtype=int)),
    'min_child_weight': hp.choice('min_child_weight', np.arange(1, 9, 1, dtype=int)),
    'colsample_bytree': hp.choice('colsample_bytree', np.arange(0.2, 0.9, 0.1)),
    'subsample':        hp.uniform('subsample', 0.8, 1),
    'feature_fraction': hp.uniform('feature_fraction', 0.5, 1),
    'n_estimators':     100,
    'num_leaves':       50,
    'bagging_fraction': hp.uniform("bagging_fraction", 0, 1.0),
}

# %%
hyperopt_objective = lambda params: evaluate(params, train_X, train_Y, validation_X, validation_Y)
best_params = fmin(hyperopt_objective, space=lgb_params_space, algo = atpe.suggest, max_evals=30)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.5941458367587039, colsample_bytree=0.7000000000000002 will be ignored. Current value: feature_fraction=0.5941458367587039
# [LightGBM] [Warning] bagging_fraction is set=0.4988638900174539, subsample=0.8573383298219807 will be ignored. Current value: bagging_fraction=0.4988638900174539
# [LightGBM] [Warning] feature_fraction is set=0.6127792259583852, colsample_bytree=0.8000000000000003 will be ignored. Current value: feature_fraction=0.6127792259583852
# [LightGBM] [Warning] bagging_fraction is set=0.8490378313107357, subsample=0.8303808217366592 will be ignored. Current value: bagging_fraction=0.8490378313107357
# [LightGBM] [Warning] feature_fraction is set=0.8597816140019531, colsample_bytree=0.7000000000000002 will be ignored. Current value: feature_fraction=0.8597816140019531
# [LightGBM] [Warning] bagging_fraction is set=0.6934508388810003, subsample=0.9441643951652329 will be ignored. Current value: bagging_fraction=0.6934508388810003
# [LightGBM] [Warning] feature_fraction is set=0.8267219313539791, colsample_bytree=0.6000000000000001 will be ignored. Current value: feature_fraction=0.8267219313539791
# [LightGBM] [Warning] bagging_fraction is set=0.1554895818939519, subsample=0.9248616602489209 will be ignored. Current value: bagging_fraction=0.1554895818939519
# [LightGBM] [Warning] feature_fraction is set=0.8734576195266862, colsample_bytree=0.2 will be ignored. Current value: feature_fraction=0.8734576195266862
# [LightGBM] [Warning] bagging_fraction is set=0.6610530709997574, subsample=0.8302834061710402 will be ignored. Current value: bagging_fraction=0.6610530709997574
# [LightGBM] [Warning] feature_fraction is set=0.984895230386861, colsample_bytree=0.30000000000000004 will be ignored. Current value: feature_fraction=0.984895230386861
# [LightGBM] [Warning] bagging_fraction is set=0.19320803135244347, subsample=0.9315574357372256 will be ignored. Current value: bagging_fraction=0.19320803135244347
# [LightGBM] [Warning] feature_fraction is set=0.7899934945662481, colsample_bytree=0.30000000000000004 will be ignored. Current value: feature_fraction=0.7899934945662481
# [LightGBM] [Warning] bagging_fraction is set=0.30491371668800926, subsample=0.8222899362534937 will be ignored. Current value: bagging_fraction=0.30491371668800926
# [LightGBM] [Warning] feature_fraction is set=0.960148527877227, colsample_bytree=0.7000000000000002 will be ignored. Current value: feature_fraction=0.960148527877227
# [LightGBM] [Warning] bagging_fraction is set=0.48632729572025735, subsample=0.8206333108150338 will be ignored. Current value: bagging_fraction=0.48632729572025735
# [LightGBM] [Warning] feature_fraction is set=0.8898202214616648, colsample_bytree=0.6000000000000001 will be ignored. Current value: feature_fraction=0.8898202214616648
# [LightGBM] [Warning] bagging_fraction is set=0.9789385613015015, subsample=0.9752143543200814 will be ignored. Current value: bagging_fraction=0.9789385613015015
# [LightGBM] [Warning] feature_fraction is set=0.8404864221480957, colsample_bytree=0.4000000000000001 will be ignored. Current value: feature_fraction=0.8404864221480957
# [LightGBM] [Warning] bagging_fraction is set=0.237417788654535, subsample=0.8938178213142473 will be ignored. Current value: bagging_fraction=0.237417788654535
# [LightGBM] [Warning] feature_fraction is set=0.5734959466636494, colsample_bytree=0.7000000000000002 will be ignored. Current value: feature_fraction=0.5734959466636494
# [LightGBM] [Warning] bagging_fraction is set=0.5760443250667224, subsample=0.8178037216783219 will be ignored. Current value: bagging_fraction=0.5760443250667224
# [LightGBM] [Warning] feature_fraction is set=0.946793005882401, colsample_bytree=0.7000000000000002 will be ignored. Current value: feature_fraction=0.946793005882401
# [LightGBM] [Warning] bagging_fraction is set=0.8916943827654978, subsample=0.978788012168644 will be ignored. Current value: bagging_fraction=0.8916943827654978
# [LightGBM] [Warning] feature_fraction is set=0.5781911501302376, colsample_bytree=0.8000000000000003 will be ignored. Current value: feature_fraction=0.5781911501302376
# [LightGBM] [Warning] bagging_fraction is set=0.8567643786073229, subsample=0.9946192770645712 will be ignored. Current value: bagging_fraction=0.8567643786073229
# [LightGBM] [Warning] feature_fraction is set=0.5599621111733978, colsample_bytree=0.8000000000000003 will be ignored. Current value: feature_fraction=0.5599621111733978
# [LightGBM] [Warning] bagging_fraction is set=0.42861276966109485, subsample=0.852031262783861 will be ignored. Current value: bagging_fraction=0.42861276966109485
# [LightGBM] [Warning] feature_fraction is set=0.5687898432410892, colsample_bytree=0.8000000000000003 will be ignored. Current value: feature_fraction=0.5687898432410892
# [LightGBM] [Warning] bagging_fraction is set=0.9670653365846814, subsample=0.8636221477909727 will be ignored. Current value: bagging_fraction=0.9670653365846814
# [LightGBM] [Warning] feature_fraction is set=0.5764624805217987, colsample_bytree=0.8000000000000003 will be ignored. Current value: feature_fraction=0.5764624805217987
# [LightGBM] [Warning] bagging_fraction is set=0.9768591581835331, subsample=0.9962897441263735 will be ignored. Current value: bagging_fraction=0.9768591581835331
# [LightGBM] [Warning] feature_fraction is set=0.6497608565901508, colsample_bytree=0.8000000000000003 will be ignored. Current value: feature_fraction=0.6497608565901508
# [LightGBM] [Warning] bagging_fraction is set=0.9144355365862362, subsample=0.9997518677783955 will be ignored. Current value: bagging_fraction=0.9144355365862362
# [LightGBM] [Warning] feature_fraction is set=0.645075076877816, colsample_bytree=0.8000000000000003 will be ignored. Current value: feature_fraction=0.645075076877816
# [LightGBM] [Warning] bagging_fraction is set=0.6475432540568051, subsample=0.9987248425498548 will be ignored. Current value: bagging_fraction=0.6475432540568051
# [LightGBM] [Warning] feature_fraction is set=0.6033689854415535, colsample_bytree=0.8000000000000003 will be ignored. Current value: feature_fraction=0.6033689854415535
# [LightGBM] [Warning] bagging_fraction is set=0.899901943037134, subsample=0.8636345572132605 will be ignored. Current value: bagging_fraction=0.899901943037134
# [LightGBM] [Warning] feature_fraction is set=0.6576818107327874, colsample_bytree=0.8000000000000003 will be ignored. Current value: feature_fraction=0.6576818107327874
# [LightGBM] [Warning] bagging_fraction is set=0.4760931107841647, subsample=0.9949932883760091 will be ignored. Current value: bagging_fraction=0.4760931107841647
# [LightGBM] [Warning] feature_fraction is set=0.6606180224662968, colsample_bytree=0.8000000000000003 will be ignored. Current value: feature_fraction=0.6606180224662968
# [LightGBM] [Warning] bagging_fraction is set=0.9973611516058865, subsample=0.8671658609527778 will be ignored. Current value: bagging_fraction=0.9973611516058865
# [LightGBM] [Warning] feature_fraction is set=0.5165846759173633, colsample_bytree=0.8000000000000003 will be ignored. Current value: feature_fraction=0.5165846759173633
# [LightGBM] [Warning] bagging_fraction is set=0.8633842437681775, subsample=0.9981743315389922 will be ignored. Current value: bagging_fraction=0.8633842437681775
# [LightGBM] [Warning] feature_fraction is set=0.6850086886011091, colsample_bytree=0.8000000000000003 will be ignored. Current value: feature_fraction=0.6850086886011091
# [LightGBM] [Warning] bagging_fraction is set=0.417910711708307, subsample=0.8623297980649698 will be ignored. Current value: bagging_fraction=0.417910711708307
# [LightGBM] [Warning] feature_fraction is set=0.681546827459687, colsample_bytree=0.8000000000000003 will be ignored. Current value: feature_fraction=0.681546827459687
# [LightGBM] [Warning] bagging_fraction is set=0.657759641576765, subsample=0.8673253388649487 will be ignored. Current value: bagging_fraction=0.657759641576765
# [LightGBM] [Warning] feature_fraction is set=0.6531782878350072, colsample_bytree=0.5000000000000001 will be ignored. Current value: feature_fraction=0.6531782878350072
# [LightGBM] [Warning] bagging_fraction is set=0.8124861287392386, subsample=0.885792030156517 will be ignored. Current value: bagging_fraction=0.8124861287392386
# [LightGBM] [Warning] feature_fraction is set=0.5035234193741996, colsample_bytree=0.8000000000000003 will be ignored. Current value: feature_fraction=0.5035234193741996
# [LightGBM] [Warning] bagging_fraction is set=0.3741515764806827, subsample=0.8484184581445204 will be ignored. Current value: bagging_fraction=0.3741515764806827
# [LightGBM] [Warning] feature_fraction is set=0.704817140287513, colsample_bytree=0.8000000000000003 will be ignored. Current value: feature_fraction=0.704817140287513
# [LightGBM] [Warning] bagging_fraction is set=0.5637533264753751, subsample=0.8724434534746818 will be ignored. Current value: bagging_fraction=0.5637533264753751
# [LightGBM] [Warning] feature_fraction is set=0.712176479569791, colsample_bytree=0.4000000000000001 will be ignored. Current value: feature_fraction=0.712176479569791
# [LightGBM] [Warning] bagging_fraction is set=0.5113698252448929, subsample=0.8772387941658567 will be ignored. Current value: bagging_fraction=0.5113698252448929
# [LightGBM] [Warning] feature_fraction is set=0.6284148730073152, colsample_bytree=0.8000000000000003 will be ignored. Current value: feature_fraction=0.6284148730073152
# [LightGBM] [Warning] bagging_fraction is set=0.7495389720967256, subsample=0.998810258730188 will be ignored. Current value: bagging_fraction=0.7495389720967256
# [LightGBM] [Warning] feature_fraction is set=0.5941458367587039, colsample_bytree=0.7000000000000002 will be ignored. Current value: feature_fraction=0.5941458367587039
# [LightGBM] [Warning] bagging_fraction is set=0.4988638900174539, subsample=0.8573383298219807 will be ignored. Current value: bagging_fraction=0.4988638900174539
# 100%|██████████| 30/30 [00:27<00:00,  1.09trial/s, best loss: 2.0581028569611277]

# %%
best_params
# Out:
# {'bagging_fraction': 0.13572948982908775,
#  'colsample_bytree': 2,
#  'feature_fraction': 0.7822838287906773,
#  'max_depth': 6,
#  'min_child_weight': 6,
#  'subsample': 0.8001090827182867}

# %% [markdown]
# ### Inference

# %%
model = MultiOutputRegressor(LGBMRegressor(**best_params))
model.fit(train_x, train_y)
preds = model.predict(test_x)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.7822838287906773, colsample_bytree=2 will be ignored. Current value: feature_fraction=0.7822838287906773
# [LightGBM] [Warning] bagging_fraction is set=0.13572948982908775, subsample=0.8001090827182867 will be ignored. Current value: bagging_fraction=0.13572948982908775

# %%
pd.DataFrame(preds)
# Out:
#              0         1         2          3          4          5   \
# 0      1.467588  1.319522  1.113390  13.495417  31.632325  16.325999
# 1      1.511584  1.200198  1.151780  13.238776  31.305611  16.616646
# 2      1.522981  1.089205  1.079396  14.808018  31.611739  16.030145
# 3      1.445916  1.147610  1.046202  15.132445  32.365255  17.045321
# 4      1.341940  0.988750  0.897432  14.766247  31.543824  16.036890
# ...         ...       ...       ...        ...        ...        ...
# 39603  1.249646  1.028987  0.973625  12.395861  31.119315  16.650385
# 39604  1.141782  0.877175  0.889475  13.909332  31.115539  16.796231
# 39605  1.228478  0.920889  0.942353  13.169269  31.158489  16.593736
# 39606  1.199388  0.907848  0.925201  13.363960  31.602884  16.722196
# 39607  1.276266  0.927955  0.997209  13.240808  30.359597  16.662247
#
#              6          7          8          9          10         11  \
# 0      3.179095 -26.182725 -26.129498 -22.240229  24.793927 -25.983009
# 1      3.137490 -26.188034 -26.171124 -22.250781  24.384505 -26.130406
# 2      3.118520 -25.889853 -26.047044 -22.127044  24.746461 -25.930416
# 3      3.120367 -25.562460 -25.698889 -21.558137  24.879319 -25.521178
# 4      3.055481 -25.851612 -25.723000 -22.033665  24.709205 -25.786045
# ...         ...        ...        ...        ...        ...        ...
# 39603  3.139597 -26.486598 -26.472974 -22.827850  24.325491 -26.447756
# 39604  3.181452 -26.411070 -26.273658 -22.596241  24.531760 -26.331629
# 39605  3.189448 -26.481018 -26.534445 -22.959768  24.238880 -26.479141
# 39606  3.187028 -26.542945 -26.474524 -22.795293  24.496016 -26.462654
# 39607  3.199510 -26.389153 -26.515837 -22.857318  24.141881 -26.498236
#
#               12         13
# 0     -25.992988 -26.035066
# 1     -26.111572 -26.127564
# 2     -26.049078 -26.068320
# 3     -25.581167 -25.575412
# 4     -25.665485 -25.598377
# ...          ...        ...
# 39603 -26.504047 -26.427559
# 39604 -26.354203 -26.267125
# 39605 -26.456460 -26.460097
# 39606 -26.460002 -26.443066
# 39607 -26.335574 -26.478671
#
# [39608 rows x 14 columns]

# %% [markdown]
# ### Save Prediction

# %%
submit = pd.read_csv('./sample_submission.csv')
for idx, col in enumerate(submit.columns):
    if col=='ID':
        continue
    submit[col] = preds[:,idx-1]
